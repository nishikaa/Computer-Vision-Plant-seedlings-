# %% [markdown]
# # Can you differenciate a weed from a crop seedling?

# %%
pip install google-colab
# Out:
# Processing c:\users\nishi\appdata\local\pip\cache\wheels\e4\e7\91\b2736701bca00e273fdc79f80e2727b558e0903d81b758eb69\google_colab-1.0.0-py2.py3-none-any.whl
# Processing c:\users\nishi\appdata\local\pip\cache\wheels\b9\10\77\cad2fb4f8ab57cc7cecb92b9b1b0548ac932b8f81774003683\portpicker-1.2.0-py3-none-any.whl
# ...
#   Using cached notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
# ...
#   Using cached requests-2.21.0-py2.py3-none-any.whl (57 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
from google.colab import files
uploaded=files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-49432676dcaa> in <module>
# ----> 1 from google.colab import files
#       2 uploaded=files.upload()
#
# ModuleNotFoundError: No module named 'google.colab'
